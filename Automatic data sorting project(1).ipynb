# %%
import os, shutil

# %%
path = r"C:\Users\USER\Downloads\Telegram Desktop/"

# %%
os.listdir(path)
# Out:
# ['1. Weather Data.csv',
#  '10-Excel-Pro-Tips-eBook-Package.zip',
#  '13618d14b54bfacd3e972e8b6081bf3dfdfe82423813ed134747923930486f00.mp4',
#  '1684951039967.jpg',
#  '2. Cars Data1(1).csv',
#  '2. Cars Data1.csv',
#  '3. Police Data(2).csv',
#  '4. covid_19_data.csv',
#  '5. London Housing Data.csv',
#  '7. Udemy Courses.csv',
#  '8. Netflix Dataset(1).csv',
#  '8. Netflix Dataset.csv',
#  'AB_NYC_2019.csv',
#  'AirBnB Data',
#  'airbnb.jpg',
#  'AllTimeRankingByClub.csv',
#  'all_data.csv',
#  'Amazon ECommerce dataset',
#  'Amazon India Sales Dashboard.pptx',
#  'amazon logo.png',
#  'Amazon Web Scraper Project.ipynb',
#  'amazon_prime_titles(1).csv',
#  'amazon_prime_titles(2).csv',
#  'amazon_prime_titles(3).csv',
#  'amazon_prime_titles(4).csv',
#  'amazon_prime_titles.csv',
#  'amount.png',
#  'Anaconda3-2023.03-1-Windows-x86_64.exe',
#  'apple.png',
#  'archive(1).zip',
#  'archive(10).3PtNNiMF.zip.part',
#  'archive(10).zip',
#  'archive(11).zip',
#  'archive(12).zip',
#  'archive(2).zip',
#  'archive(3).zip',
#  'archive(4).zip',
#  'archive(5).zip',
#  'archive(6).zip',
#  'archive(7).zip',
#  'archive(8).zip',
#  'archive(9).zip',
#  'archive.zip',
#  'Argentina flag(1).jfif',
#  'Argentina flag.jfif',
#  'arminius.jpg',
#  'Arrows(1).txt',
#  'Arrows(2).txt',
#  'Arrows(3).txt',
#  'Arrows.txt',
#  'athlete_events.csv.zip',
#  'Bar graph.png',
#  'Bike Store Dashboard.png',
#  'BIKE STORE.png',
#  'bIKE.png',
#  'BikeStores.xlsx',
#  'Brazil flag.png',
#  'Breaking Bad Dataset.csv',
#  'Breaking Bad description - Wikipedia.txt',
#  'Breaking Bad(1).png',
#  'Breaking Bad.png',
#  'Breaking_Bad.jpg',
#  'Breaking_Bad_Logo.png',
#  'burris.jpg',
#  'cap screws.jpg',
#  'Category.png',
#  'Champions League Dashboard(1).png',
#  'Champions League Dashboard.png',
#  'Champions league Data',
#  'Champions league logo.jpg',
#  'Champions League Stats.pdf',
#  'ChatGPT for Teachers 2023(1).pptx',
#  'ChatGPT for Teachers 2023.pptx',
#  'ChromeSetup.exe',
#  'Clerical_Job_Video_Ad_production_story_12756_1_1_1603801977756_SD3.mp4',
#  'CoachesAppearTotals.csv',
#  'Collins Kimathi Mwiti - Resume.pdf',
#  'Collins Kimathi Mwiti.docx',
#  'Collins Kimathi Mwiti.jpg',
#  'Collins Kimathi Mwiti_075108.pdf',
#  'Collins Mwiti_075104.pdf',
#  'Collins Portfolio project.sql',
#  'collo Netflix.ipynb',
#  'Conditional Formatting Excel Tutorial File.xlsx',
#  'Covid tracker project (Tableau).txt',
#  'COVID Tracker.png',
#  'covid19-download.xlsx',
#  'Credit Card Dashboard.xlsx',
#  'Customer Call List.xlsx',
#  'Dashboard 1.pdf',
#  'Dashboard 1.png',
#  'Dashboard.png',
#  'Data Analyst Interview Questions.docx',
#  'DATA ANALYST ROADMAP 2.0 Syllabus.pdf',
#  'Data Analytics Bootcamp Certification of Completion.png',
#  'data analytics video.mp4',
#  'Data Science Salary data',
#  'Data Scientist Jobs Dashboard.png',
#  'Data Tutorial data',
#  'Dataco (Abhijit database)_Dataco.csv',
#  'db_dump(2).sql',
#  'directory.csv',
#  'directory.csv.zip',
#  'Documents - Shortcut.lnk',
#  'drive-download-20230502T050151Z-001.zip',
#  'drive-download-20230502T050509Z-001.zip',
#  'Ecommerce Analytics.pptx',
#  'eddystone 1917.jpg',
#  'Elly Omondi.pdf',
#  'Employee_Salaries.csv',
#  'England flag.png',
#  'Excel Exercise Files.zip',
#  'Excel icon.png',
#  'Excel Project Dataset.xlsx',
#  'fb.png',
#  'fifa21 raw data v2.csv',
#  'FinModel.xlsx',
#  'Firefox Installer (1).exe',
#  'Firefox Installer.exe',
#  'Fiverr gig video.mp4',
#  'fiverr logo.png',
#  'Fiverr swipe files',
#  'France Flag.jpg',
#  'Friends dataset.csv',
#  'Friends(1).jpg',
#  'Friends(2).jpg',
#  'Friends(3).jpg',
#  'Friends.jpg',
#  'Friends.png',
#  'Germany flag.png',
#  'Git-2.41.0-64-bit.exe',
#  'GitHubDesktopSetup-x64.exe',
#  'google.jpg',
#  'gun trigger.jpg',
#  'Heat Map.png',
#  'hexmap(1).xlsx',
#  'hexmap.xlsx',
#  'hotel_revenue_historical_full-2.bMFrU_qs.xlsx.part',
#  'hotel_revenue_historical_full-2.xlsx',
#  'hrdata.csv',
#  'HTML Massively',
#  'html5up-paradigm-shift.zip',
#  'Human Resources(1).csv',
#  'Human Resources(2).csv',
#  'Human Resources(3).csv',
#  'Human Resources(4).csv',
#  'Human Resources.csv',
#  'IBM HR DATA',
#  'IBM_logo.svg.png',
#  'images',
#  'Images-20230502T050143Z-001.zip',
#  'Images-20230502T050146Z-001.zip',
#  'img.png',
#  'inr.png',
#  'Inventory Management Tool_practice file.xlsm',
#  'istockphoto-1319925053-640_adpp_is.mp4',
#  'Italy flag.png',
#  'iver 32.jpg',
#  'K42DQ5VY3FSE5HEB.mp4',
#  'Lean excel',
#  'leupold.jpg',
#  'Mall_Customers.csv',
#  'marketing_campaign.csv',
#  'May 2023 Transacion Detail.xls',
#  'My first excel project.xlsx',
#  'My online training hub',
#  'My sql.png',
#  'mysql-connector-net-8.0.33(4).msi',
#  'mysql-connector-odbc-8.0.33-winx64.msi',
#  'mysql-connector-odbc-noinstall-8.0.33-winx64.zip',
#  'mysql-installer-community-8.0.33.0.msi',
#  'mysql-installer-web-community-8.0.33.0.msi',
#  'mysql-workbench-community-8.0.33-winx64.msi',
#  'Negotating Salary.docx',
#  'Netflix Data analytics.ipynb',
#  'Netflix Data analytics.py',
#  'Netflix.png',
#  'netflix_titles(1).csv',
#  'netflix_titles.csv',
#  'New-Data.zip',
#  'nvidia.png',
#  'owid-covid-data.bozDXxOd.csv.part',
#  'owid-covid-data.csv',
#  'owid-covid-data.TliVjmt5.xlsx.part',
#  'owid-covid-data.xlsx',
#  'p point.png',
#  'Pandas Sales Analysis',
#  'pdf.png',
#  'pexels-tima-miroshnichenko-7578607-4096x2160-25fps.mp4',
#  'pgadmin4-7.1-x64.exe',
#  'PlayerAppearDetails.csv',
#  'PlayerGoalTotals.csv',
#  'png2jpg',
#  'png2jpg.zip',
#  'portfolio',
#  'postgresql-15.2-2-windows-x64.exe',
#  'Power BI -  Data Analyst',
#  'Power BI -  Data Analystcsv files',
#  'Power BI -  Data Analystimage files',
#  'Power BI.jpg',
#  'products logo.png',
#  'project 1.sql',
#  'project tasks_data_mito.csv',
#  'quality 2.mp4',
#  'quality 3.mp4',
#  'quality 4.mp4',
#  'Quality service.mp4',
#  'quantity logo.png',
#  'queries.docx',
#  'QUESTIONS TAB.sql',
#  'Radial Bar chart values.txt',
#  'README(1).md',
#  'README.md',
#  'receipt.pdf',
#  'regression-tableau.csv',
#  'Regression_Analysis_Trend_Clustering_Solution.pptx',
#  'Reports.zip',
#  'Ressources.rar',
#  'review_data.csv',
#  'RGV4K8ZDPF68LNDK.mp4',
#  'rifle.pdf',
#  'Sales Dashboard Background.pptx.jpg',
#  'Sales Data Analysis.ipynb',
#  'Sales Data(1).xls',
#  'Sales Data.xls',
#  'Sales insight data',
#  'sales-insights-data-analysis-project(2).zip',
#  'Sales.csv.zip',
#  'SalesAnalysis.ipynb',
#  'Sample Resume 2.docx',
#  'Sample Resume.docx',
#  'sample_-_superstore.xls',
#  'size logo.png',
#  'Spain flag.jpg',
#  'SQL Test Document_Power BI.docx',
#  'SQL Test Document_Tableau.docx',
#  'SQL-Server-Sample-Database(1)',
#  'SQL-Server-Sample-Database(1).zip',
#  'SQL-Server-Sample-Database.zip',
#  'SQL2022-SSEI-Dev(1).exe',
#  'SQL2022-SSEI-Dev.exe',
#  'SQL2022-SSEI-Eval(1).exe',
#  'SQL2022-SSEI-Eval.exe',
#  'SQL2022-SSEI-Expr(1).exe',
#  'SQL2022-SSEI-Expr(2).exe',
#  'SQL2022-SSEI-Expr(3).exe',
#  'SQL2022-SSEI-Expr(5).exe',
#  'SQL2022-SSEI-Expr(7).exe',
#  'SQL2022-SSEI-Expr.exe',
#  'SQLEXPR_x64_ENU',
#  'SQLEXPR_x64_ENU.exe',
#  'SSMS-Setup-ENU(1).exe',
#  'SSMS-Setup-ENU.exe',
#  'steel core.jpg',
#  'Stock Market Dashboard(1).png',
#  'Stock Market Dashboard(2).png',
#  'Stock Market Dashboard(3).png',
#  'Stock Market Dashboard.png',
#  'Stock Market Data Analysis.ipynb',
#  'Stock Market(1).ipynb',
#  'Stock Market(2).ipynb',
#  'Stock Market(3).ipynb',
#  'Stock Market.ipynb',
#  'Stocks Data',
#  'superstore_sales.xlsx',
#  'Survey Dataset - Technical Interview(1).csv',
#  'Survey Dataset - Technical Interview.csv',
#  'Survey Dataset - Technical Interview.oMBgPURH.csv.part',
#  'Tableau customer complaint data and dashboard',
#  'Tableau final project data',
#  'Tableau icon.png',
#  'Tableau IPL Analysis',
#  'Tableau Joins File.xlsx',
#  'Tableau-Logo-for-website.jpg',
#  'Tableau.png',
#  'TableauAutoUpdate',
#  'TableauPublicDesktop-64bit-2023-1-0.exe',
#  'talley.jpg',
#  'Tax Compliance Certificate.pdf',
#  'Telegram Desktop',
#  'tesla.jpg',
#  'TopGoalScorer.csv',
#  'Total Companies by size and Location.png',
#  'Total Employees by Education Field.png',
#  'trigger.jpg',
#  'Tripadvisor Hotels Dashboard.png',
#  'tripadvisor-logo(1).png',
#  'tripadvisor-logo(2).png',
#  'tripadvisor-logo.png',
#  'tsetup-x64.4.7.1.exe',
#  'Twitter.jpg',
#  'twitter.png',
#  'UK Census to Predict Occupation Project.pdf',
#  'Upwork swipe files',
#  'Upwork Video.mp4',
#  'upwork.png',
#  'uruguay flag(1).png',
#  'uruguay flag.png',
#  'VG Sales DashBoard(1).png',
#  'VG Sales DashBoard.png',
#  'VG Sales Dataset',
#  'vgsales.csv',
#  'vgsales.csv.zip',
#  'video 2.mp4',
#  'video 3.mp4',
#  'video 4.mp4',
#  'video 5.mp4',
#  'video 6.mp4',
#  'voicebooking-speech.wav',
#  'Volume_Full Data_data.csv',
#  'Vrinda Store Data Analysis.xlsx',
#  'VSCodeUserSetup-x64-1.77.1.exe',
#  'warne.jpg',
#  'Web Scraped data',
#  'What to say vs what NOT to say in a Data Analyst Interview.docx',
#  'Wikipedia Web Data scraping.ipynb',
#  'World Cup logo.png',
#  'World population data exploration.ipynb',
#  'world_cup_results(1).xlsx',
#  'world_cup_results.xlsx',
#  'world_population.csv',
#  'XLOOKUP Excel Tutorial File.xlsx']

# %%
folder_names = ['csv files', 'image files', 'text files']

for loop in range (0,3):

    if not os.path.exists(path + folder_names[loop]):
        print(path + folder_names[loop])
        os.makedirs(path + folder_names[loop])
# Out:
# C:\Users\USER\Downloads\Telegram Desktop/csv files
# C:\Users\USER\Downloads\Telegram Desktop/image files
# C:\Users\USER\Downloads\Telegram Desktop/text files

# %%
file_name = os.listdir(path)

# %%
folder_names = ['csv files', 'image files', 'text files']

for loop in range(0,3):
    if not os.path.exists(path + folder_names[loop]):
        print(path + folder_names[loop])
        os.makedirs((path + folder_names[loop]))

# %%
for file in file_name:
    if ".csv" in file and not os.path.exists(path + "csv files/" + file):
        shutil.move(path + file, path + "csv files/" + file)
    elif ".png" in file and not os.path.exists(path + "image files/" + file):
        shutil.move(path + file, path + "image files/" + file)
    elif ".txt" in file and not os.path.exists(path + "text files/" + file):
        shutil.move(path + file, path + "text files/" + file)
    elif ".pdf" in file and not os.path.exists(path + "text files/" + file):
        shutil.move(path + file, path + "text files/" + file)
    elif ".xlsx" in file and not os.path.exists(path + "text files/" + file):
        shutil.move(path + file, path + "text files/" + file)
    else:
        print("The files were fully moved!")
# Out:
# The files were fully moved!
# The files were fully moved!
# The files were fully moved!
# The files were fully moved!
# The files were fully moved!
# The files were fully moved!
# The files were fully moved!
# The files were fully moved!
# The files were fully moved!
# The files were fully moved!
# The files were fully moved!
# The files were fully moved!
# The files were fully moved!
# The files were fully moved!
# The files were fully moved!
